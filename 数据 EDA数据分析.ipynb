# %%
import pandas as pd
import geopandas as gpd
import folium
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from folium.plugins import MarkerCluster
from IPython.display import display
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.chdir('E:\Python code\EDA 数据')

# %%
df = pd.read_csv('Library_Services_20240831.csv')
print(df.info())
print(df.isnull().sum())
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Columns: 105 entries, Branch to Location
# dtypes: float64(18), int64(4), object(83)
# memory usage: 17.4+ KB
# None
# Branch         0
# Webpage        0
# Address        0
# City           0
# Zip            0
#               ..
# metrobus Z6    0
# metrobus Z9    0
# Latitude       0
# Longitude      0
# Location       0
# Length: 105, dtype: int64
# Index(['Branch', 'Webpage', 'Address', 'City', 'Zip', 'Square Feet',
#        'Inventory', 'Population Size', 'Phone', 'TTY Phone',
#        ...
#        'metrobus Q1', 'metrobus Q2', 'metrobus T2', 'metrobus z2',
#        'metrobus Z8', 'metrobus Z6', 'metrobus Z9', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object', length=105)

# %% [markdown]
# # EDA

# %%
df = df[['Branch', 'Square Feet', 'Inventory', 'Latitude', 'Longitude']]

df.columns = df.columns.str.lower().str.replace(' ', '_')

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))

# Geospatial Analysis
m = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=12)


for idx, row in df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['branch']).add_to(m)

m.save('library_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_398482b4361b50d0417275ba6ca5e548 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_398482b4361b50d0417275ba6ca5e548&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_398482b4361b50d0417275ba6ca5e548 = L.map(
#                 &quot;map_398482b4361b50d0417275ba6ca5e548&quot;,
#                 {
#                     center: [39.07747307619048, -77.1211589047619],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b8eb73b4e41f0c3e813a00e588718f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8b8eb73b4e41f0c3e813a00e588718f1.addTo(map_398482b4361b50d0417275ba6ca5e548);
#
#
#             var marker_2043d64f856d0f13ee148db2ede17b58 = L.marker(
#                 [39.079524, -77.088752],
#                 {}
#             ).addTo(map_398482b4361b50d0417275ba6ca5e548);
#
#
#         var popup_0f6393dd517e7ff3ed480ea8e7843341 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48f7ca2b8f5f1376f7698f874d534155 = $(`&lt;div id=&quot;html_48f7ca2b8f5f1376f7698f874d534155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aspen Hill&lt;/div&gt;`)[0];
#                 popup_0f6393dd517e7ff3ed480ea8e7843341.setContent(html_48f7ca2b8f5f1376f7698f874d534155);
#
#
#
#         marker_2043d64f856d0f13ee148db2ede17b58.bindPopup(popup_0f6393dd517e7ff3ed480ea8e7843341)
#         ;
#
#
#
#
#             var marker_79256fa9c78aa8a1b9e0e8f41eabfe1b = L.marker(
#                 [39.158089, -77.205466],
#                 {}
#             ).addTo(map_398482b4361b50d0417275ba6ca5e548);
#
#
#         var popup_428382ae4c5640c4b94f51974edae80d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4cc238ee43ed7a9fa83614d235ee1ee = $(`&lt;div id=&quot;html_c4cc238ee43ed7a9fa83614d235ee1ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gaithersburg&lt;/div&gt;`)[0];
#                 popup_428382ae4c5640c4b94f51974edae80d.setContent(html_c4cc238ee43ed7a9fa83614d235ee1ee);
#
#
#
#         marker_79256fa9c78aa8a1b9e0e8f41eabfe1b.bindPopup(popup_428382ae4c5640c4b94f51974edae80d)
#         ;
#
#
#
#
#             var marker_ff27ac61c97e6ad1bd47ebe3ccbd5bcd = L.marker(
#                 [39.145139, -77.410286],
#                 {}
#             ).addTo(map_398482b4361b50d0417275ba6ca5e548);
#
#
#         var popup_a3ff852b983ee637236f8db3c733cb7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c911d688a92ae9829d7da6f0a6d79ac = $(`&lt;div id=&quot;html_4c911d688a92ae9829d7da6f0a6d79ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Maggie Nightingale&lt;/div&gt;`)[0];
#                 popup_a3ff852b983ee637236f8db3c733cb7d.setContent(html_4c911d688a92ae9829d7da6f0a6d79ac);
#
#
#
#         marker_ff27ac61c97e6ad1bd47ebe3ccbd5bcd.bindPopup(popup_a3ff852b983ee637236f8db3c733cb7d)
#         ;
#
#
#
#
#             var marker_99e3bfc9f0e19784e77cc04b26ea8e2e = L.marker(
#                 [39.019274, -77.207797],
#                 {}
#             ).addTo(map_398482b4361b50d0417275ba6ca5e548);
#
#
#         var popup_9ec2504dc08bac86657b4f1e9084089c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d73ae492299230a14ba4900903d5901 = $(`&lt;div id=&quot;html_4d73ae492299230a14ba4900903d5901&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Potomac&lt;/div&gt;`)[0];
#                 popup_9ec2504dc08bac86657b4f1e9084089c.setContent(html_4d73ae492299230a14ba4900903d5901);
#
#
#
#         marker_99e3bfc9f0e19784e77cc04b26ea8e2e.bindPopup(popup_9ec2504dc08bac86657b4f1e9084089c)
#         ;
#
#
#
#
#             var marker_550a3f7a7a7812b7ea5f3161098551ab = L.marker(
#                 [39.048025, -76.992139],
#                 {}
#             ).addTo(map_398482b4361b50d0417275ba6ca5e548);
#
#
#         var popup_55214b9e8ef56e6c5bf79d65c07c9218 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc61ed4122d0386c53bb8025a86219d0 = $(`&lt;div id=&quot;html_bc61ed4122d0386c53bb8025a86219d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;White Oak&lt;/div&gt;`)[0];
#                 popup_55214b9e8ef56e6c5bf79d65c07c9218.setContent(html_bc61ed4122d0386c53bb8025a86219d0);
#
#
#
#         marker_550a3f7a7a7812b7ea5f3161098551ab.bindPopup(popup_55214b9e8ef56e6c5bf79d65c07c9218)
#         ;
#
#
#
#
#             var marker_0af549ee076ce28bb716a92b2199d468 = L.marker(
#                 [38.991186, -77.076594],
#                 {}
#             ).addTo(map_398482b4361b50d041727

# %%
X = df[['square_feet']]
y = df['inventory']

model = LinearRegression()
model.fit(X, y)
predictions = model.predict(X)


print(df[['square_feet', 'inventory']].describe())


correlation_matrix = df[['square_feet', 'inventory']].corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)

# Visualize correlation
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# Scatter plot
sns.scatterplot(x='square_feet', y='inventory', data=df)
plt.title("Square Feet vs. Inventory")
plt.show()
# Out:
#         square_feet      inventory
# count     21.000000      21.000000
# mean   26812.285714   90176.142857
# std    23608.740361   41029.650207
# min      925.000000   12072.000000
# 25%    16000.000000   73559.000000
# 50%    16895.000000   87423.000000
# 75%    27280.000000  110165.000000
# max    90000.000000  176961.000000
#
# Correlation Matrix:
#              square_feet  inventory
# square_feet     1.000000   0.656394
# inventory       0.656394   1.000000

# %%
plt.scatter(df['square_feet'], df['inventory'], color='blue')
plt.plot(df['square_feet'], predictions, color='red')
plt.title("Linear Regression: Square Feet vs. Inventory")
plt.xlabel("Square Feet")
plt.ylabel("Inventory")
plt.show()

df['inventory_per_sqft'] = df['inventory'] / df['square_feet']
print("\nResource Utilization (Inventory per Square Foot):")
print(df[['branch', 'inventory_per_sqft']])


sns.barplot(x='branch', y='inventory_per_sqft', data=df)
plt.xticks(rotation=90)
plt.title("Resource Utilization by Library Branch")
plt.ylabel("Inventory per Square Foot")
plt.show()
# Out:
# Resource Utilization (Inventory per Square Foot):
#                 branch  inventory_per_sqft
# 0           Aspen Hill            4.884907
# 1         Gaithersburg            2.447901
# 2   Maggie Nightingale            6.152960
# 3              Potomac            5.789250
# 4            White Oak            5.814070
# 5          Chevy Chase            5.820299
# 6           Germantown            4.004277
# 7          Long Branch            3.199534
# 8                Olney            3.872730
# 9       Connie Morella            4.748827
# 10       Silver Spring            1.315522
# 11               Noyes           13.050811
# 12     Kensington Park            4.597437
# 13            Damascus            4.937256
# 14           Twinbrook            3.814916
# 15           Rockville            1.880922
# 16    Marilyn Praisner            5.086629
# 17        Little Falls            6.563304
# 18             Wheaton            0.723437
# 19               Davis            5.901875
# 20      Quince Orchard            6.123339

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['square_feet'], kde=True)
plt.title("Distribution of Square Feet")

plt.subplot(1, 2, 2)
sns.histplot(df['inventory'], kde=True)
plt.title("Distribution of Inventory")

plt.show()

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df['square_feet'])
plt.title("Box Plot of Square Feet")

plt.subplot(1, 2, 2)
sns.boxplot(x=df['inventory'])
plt.title("Box Plot of Inventory")

plt.show()

# %%
top_n = 10

top_inventory_branches = df.nlargest(top_n, 'inventory')
top_square_feet_branches = df.nlargest(top_n, 'square_feet')

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.barplot(x='inventory', y='branch', data=top_inventory_branches)
plt.title(f"Top {top_n} Branches by Inventory")

plt.subplot(1, 2, 2)
sns.barplot(x='square_feet', y='branch', data=top_square_feet_branches)
plt.title(f"Top {top_n} Branches by Square Feet")

plt.show()

# %%
cluster_map = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=12)
marker_cluster = MarkerCluster().add_to(cluster_map)

for idx, row in df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['branch']).add_to(marker_cluster)

display(cluster_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_616c330651684bb5ed3365db56c3a5e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_616c330651684bb5ed3365db56c3a5e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_616c330651684bb5ed3365db56c3a5e8 = L.map(
#                 &quot;map_616c330651684bb5ed3365db56c3a5e8&quot;,
#                 {
#                     center: [39.07747307619048, -77.1211589047619],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfa9505e3f31b2ae06a14cd134e012f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dfa9505e3f31b2ae06a14cd134e012f6.addTo(map_616c330651684bb5ed3365db56c3a5e8);
#
#
#             var marker_cluster_924cb0a81dd3bbdf5bcbb18f4cadd2cd = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_323489393a60bccb6b028e7a7033965e = L.marker(
#                 [39.079524, -77.088752],
#                 {}
#             ).addTo(marker_cluster_924cb0a81dd3bbdf5bcbb18f4cadd2cd);
#
#
#         var popup_b6f085fcb283bdd96bca07329e6c9463 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb523bcfb5cf18e7214aa7cec0f68e9b = $(`&lt;div id=&quot;html_cb523bcfb5cf18e7214aa7cec0f68e9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aspen Hill&lt;/div&gt;`)[0];
#                 popup_b6f085fcb283bdd96bca07329e6c9463.setContent(html_cb523bcfb5cf18e7214aa7cec0f68e9b);
#
#
#
#         marker_323489393a60bccb6b028e7a7033965e.bindPopup(popup_b6f085fcb283bdd96bca07329e6c9463)
#         ;
#
#
#
#
#             var marker_310651459fa5980cac1663dadf98f9a2 = L.marker(
#                 [39.158089, -77.205466],
#                 {}
#             ).addTo(marker_cluster_924cb0a81dd3bbdf5bcbb18f4cadd2cd);
#
#
#         var popup_ed39cf2a86d5b28f60fdcc871b60629b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b1a3e4d0fbbb1f7b8fe1a9fc6ffc8cc = $(`&lt;div id=&quot;html_7b1a3e4d0fbbb1f7b8fe1a9fc6ffc8cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gaithersburg&lt;/div&gt;`)[0];
#                 popup_ed39cf2a86d5b28f60fdcc871b60629b.setContent(html_7b1a3e4d0fbbb1f7b8fe1a9fc6ffc8cc);
#
#
#
#         marker_310651459fa5980cac1663dadf98f9a2.bindPopup(popup_ed39cf2a86d5b28f60fdcc871b60629b)
#         ;
#
#
#
#
#             var marker_ac180e0ce12cb4f0e2b72d1c3a619d5f = L.marker(
#                 [39.145139, -77.410286],
#                 {}
#             ).addTo(marker_cluster_924cb0a81dd3bbdf5bcbb18f4cadd2cd);
#
#
#         var popup_3c7be331b2f39c6057714e3b8b028917 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5279b5cbadd24c5d8a894d15aeae3d3 = $(`&lt;div id=&quot;html_f5279b5cbadd24c5d8a894d15aeae3d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Maggie Nightingale&lt;/div&gt;`)[0];
#                 popup_3c7be331b2f39c6057714e3b8b028917.setContent(html_f5279b5cbadd24c5d8a894d15aeae3d3);
#
#
#
#         marker_ac180e0ce12cb4f0e2b72d1c3a619d5f.bindPopup(popup_3c7be331b2f39c6057714e3b8b028917)
#         ;
#
#
#
#
#             var marker_26e2865506415c4fcb021b686f33340d = L.marker(
#                 [39.019274, -77.207797],
#                 {}
#             ).addTo(marker_cluster_924cb0a81dd3bbdf5bcbb18f4cadd2cd);
#
#
#         var popup_4f1b65c199bdb975f40c657a32d9c52e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d983a36f5924724a00744e1c09428844 = $(`&lt;div id=&quot;html_d983a36f5924724a00744e1c09428844&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Potomac&lt;/div&gt;`)[0];
#                 popup_4f1b65c199bdb975f40c657a32d9c52e.setContent(html_d983a36f5924724a00744e1c09428844);
#
#
#
#         marker_26e2865506415c4fcb021b686f33340d.bindPopup(popup_4f1b65c199bdb975f40c657a32d9c52e)
#         ;
#
#
#
#
#             var marker_9a873ece0473d04f03a3136ceff8e9f9 = L.marker(
#                 [39.048025, -76.992139],
#                 {}
#             ).addTo(marker_cluster_924cb0a81dd3bbdf5bcbb18f4cadd2cd);
#
#
#         var popup_aff8aed4b1c5a61c1a0546dec9a3358e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
